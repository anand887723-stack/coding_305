# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('D:\\Downloads\\final_result.csv')

# Display the DataFrame
# print(df)

# %%
df.tail(10)
# Out:
#              1          2          3          4          5          6  \
# 252  28.520000  29.120001  28.610001  28.719999  28.940001  29.520000
# 253  33.380001  33.689999  33.130001  32.910000  32.919998  32.889999
# 254  35.689999  35.990002  36.029999  35.930000  35.889999  36.650002
# 255  34.189999  34.250000  34.470001  34.570000  34.450001  34.349998
# 256  28.209999  28.209999  27.450001  27.410000  28.430000  28.129999
# 257  25.990000  26.110001  25.230000  25.160000  24.770000  24.930000
# 258  25.990000  26.110001  25.230000  25.160000  24.770000  24.930000
# 259  28.309999  27.309999  27.290001  32.560001  28.350000  28.350000
# 260  20.230000  20.230000  29.510000  29.430000  29.549999  23.309999
# 261  28.670000  29.170000  29.070000  28.809999  28.610001  28.530001
#
#              7          8          9         10  ...  4599_sarima_pred  \
# 252  29.600000  29.209999  29.150000  29.110001  ...         34.946412
# ...

# %%
new_df= df[['1','1_sarima_pred']]
x = new_df['1'] - new_df['1_sarima_pred']

# Print the DataFrame with the new 'Difference' column
for  i in x: 
    print(i)
# Out:
# 0.00017125012699636954
# 1.891590763136719e-06
# 4.182167698019157e-05
# -1.281081462423117e-05
# 2.7788273904150174e-05
# -2.5412032385929706e-05
# -3.954673767481154e-05
# 4.4921475407022626e-05
# -2.1692125741878954e-05
# -6.672390319550914e-05
# 3.652082293470471e-05
# -15.73016554922966
# -5.610327179232634
# -2.2821914240359433
# 4.574569148342192
# -0.12136700313142512
# -1.542109618217225
# 4.355151107557756
# -2.763131232278319
# 0.03407309375115375
# 5.603660910533744
# 5.687060058690378
# -3.663693373001859
# 0.5734164790664558
# -2.0953136932685155
# -4.182546150828628
# -0.8979124698414793
# 5.985355250597678
# 4.435046090799283
# 5.364548174082145
# -0.5836349514862462
# -5.949557282326396
# 3.3145688224573533
# 0.1696117360825724
# -1.323044485769941
# -0.6241202363249911
# -7.204044281907919
# -2.374606544557494
# 0.9613633478623953
# -3.0629026505065724
# -1.7110076299238415
# -1.6573054456943304
# 0.8700597091463287
# -3.508282323197257
# 3.6270277928647694
# ...

# %%
import matplotlib as plt


first_array = df.iloc[:, :4608].to_numpy()[260]
# Extract the next 6 columns into a NumPy array
second_array = df.iloc[:, -4608:].to_numpy()[260]



# arr = arr.to_numpy().reshape(64, 72)
# predme = predme.reshape(64, 72)

# max_ = max(np.max(arr), np.max(predme))
# min_ = min(np.min(arr), np.min(predme))

# plt.imshow(arr, cmap='coolwarm', vmax=max_, vmin=min_)
# plt.colorbar(label='Color')
# plt.title('Actual')
# plt.axis('off')
# f
# plt.show()

# %%
import numpy as np

# Assuming that `first_array` and `second_array` have been defined as mentioned in your code

# Reshape the first_array into a 72x64 array
first_array = first_array.reshape(64,72)

# Reshape the second_array into a 72x64 array
second_array = second_array.reshape(64,72)

# %%
import matplotlib.pyplot as plt

# Your code

# Display an image using imshow
# plt.imshow(your_image)
# plt.show()

# %%
# nan_indices = np.isnan(first_array).sum()

# # Print the indices of NaN values
# print(nan_indices)
first_array
# Out:
# array([[20.22999954, 20.22999954, 29.51000023, ..., 27.44000053,
#         27.18000031, 26.98999977],
#        [20.22999954, 20.22999954, 29.51000023, ..., 28.22999954,
#         28.10000038, 27.51000023],
#        [29.19000053, 29.29000092, 29.35000038, ..., 28.18000031,
#         28.35000038, 27.73999977],
#        ...,
#        [29.29000092, 28.60000038, 28.81999969, ..., 30.82999992,
#         30.79999924, 30.79000092],
#        [29.        , 29.11000061, 29.53000069, ..., 31.43000031,
#         31.37999916, 31.38999939],
#        [29.45000076, 31.        , 30.45000076, ..., 31.07999992,
#         31.32999992, 31.31999969]])

# %%
second_array
# Out:
# array([[27.49470436, 27.04815067, 26.83531617, ..., 28.30085963,
#         27.03034643, 25.96218082],
#        [18.5255592 , 27.15883912, 26.01440046, ..., 27.0875145 ,
#         27.12222035, 27.58303032],
#        [26.52805507, 27.11484015, 26.38075104, ..., 27.40887009,
#         27.8333158 , 28.29379765],
#        ...,
#        [27.07769513, 26.6811022 , 26.62202445, ..., 26.31402409,
#         26.69773775, 29.3979111 ],
#        [26.13593983, 27.02008035, 26.82906859, ..., 28.08105231,
#         28.65437955, 29.27948923],
#        [27.1888094 , 26.744488  , 25.432916  , ..., 28.25633525,
#         26.64352872, 27.13616851]])

# %%
max1 = np.max(first_array)
max2 = np.max(second_array)

min1 = np.min(first_array)
min2 = np.min(second_array)
plt.imshow(first_array, cmap='coolwarm', vmax=35, vmin=10)
plt.colorbar(label='Color')
plt.title('Actual')
plt.axis('off')

plt.show()
# print( min_)
# print

# %%
plt.imshow(second_array, cmap='coolwarm', vmax=35, vmin=5)
plt.colorbar(label='Color')
plt.axis('off')
plt.title("Prediction")
plt.show()

# %%
import numpy as np
arr = first_array.to_numpy().reshape(64, 72)
predme = second_array.reshape(64, 72)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Desktop\coding_305\image_formation.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/c%3A/Desktop/coding_305/image_formation.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> import numpy as np
# ----> <a href='vscode-notebook-cell:/c%3A/Desktop/coding_305/image_formation.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> arr = first_array.to_numpy().reshape(64, 72)
#       <a href='vscode-notebook-cell:/c%3A/Desktop/coding_305/image_formation.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> predme = second_array.reshape(64, 72)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_numpy'
